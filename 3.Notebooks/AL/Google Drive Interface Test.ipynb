# %% [markdown]
# # Setup

# %%
from google.colab import drive, auth
import sys

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/andrew-loeber/proj_utils_207.git
# Out:
# Cloning into 'proj_utils_207'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 31 (delta 9), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (31/31), 7.98 KiB | 817.00 KiB/s, done.

# %%
sys.path.insert(1, "/content/proj_utils_207")

# %%
auth.authenticate_user()
gcloud_token = !gcloud auth print-access-token
gcloud_token
# Out:
# ['ya29.a0AbVbY6OldrDCA6AFN0KuDTGBust8XON_laykYtY14sF1QCQ4vLCj_TO7Y0aLbx0frNIYwAajNDQj9WGpCqL0qDJyoYBOR1Zt3ubmEixTaEugL-KBMqhqj3QSNf1QGbImA2vfdqs130d8lqc_vNMO1EBgLCYAaCgYKASMSARASFQFWKvPlz1tkgjWitsXx1JDGFZHN8g0163']

# %%
from gdriveinterface import GDriveInterface

# %%
gdi = GDriveInterface(gcloud_token)
gdi.__dict__
# Out:
# {'email': 'aloeber@berkeley.edu',
#  'account': 'aloeber',
#  'shared_folder_path': '/content/drive/MyDrive/207-Project'}

# %% [markdown]
# # Check for correct file paths

# %%
gdi.get_file_path('taxonomy')
# Out:
# '/content/drive/MyDrive/207-Project/BirdCLEF/eBird_Taxonomy_v2021.csv'

# %%
gdi.get_dir_path('orig_audio')
# Out:
# '/content/drive/MyDrive/207-Project/BirdCLEF/train_audio'

# %%
gdi.get_sample_path('train_audio', 'barswa/XC132406.ogg')
# Out:
# '/content/drive/MyDrive/207-Project/data/train/audio_files/barswa/XC132406.ogg'

# %%
gdi.join_to_shared('images/sandpiper.jpeg')
# Out:
# '/content/drive/MyDrive/207-Project/images/sandpiper.jpeg'
