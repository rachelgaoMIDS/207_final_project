# %% [markdown]
# # Import Libraries

# %%
# Standard libraries
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 300)

# for audio files
import librosa

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load training data csv file

# %%
df = pd.read_csv('/content/drive/MyDrive/207/207-Project/data/test_metadata.csv')

df.head()
# Out:
#   primary_label         common_name    scientific_name  species_rank  \
# 0       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 1       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 2       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 3       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 4       thrnig1  Thrush Nightingale  Luscinia luscinia             0
#
#                filename dataset  duration_secs  duration_mins  duration_hrs  \
# 0  thrnig1/XC112492.ogg    test      58.540408       0.975673      0.016261
# 1  thrnig1/XC132295.ogg    test      73.769796       1.229497      0.020492
# 2  thrnig1/XC133558.ogg    test      78.759229       1.312654      0.021878
# 3  thrnig1/XC134265.ogg    test     394.187755       6.569796      0.109497
# 4  thrnig1/XC135792.ogg    test      42.344535       0.705742      0.011762
#
#    species_total_files  ...  rating  latitude  longitude            author  \
# 0                  499  ...     3.0   59.8510    17.6230        Sander Bot
# 1                  499  ...     3.0   56.0889    47.2543  Albert Lastukhin
# 2                  499  ...     4.5   61.5650    29.5650     Stuart Fisher
# 3                  499  ...     5.0   51.3506    23.0467    Jarek Matusiak
# 4                  499  ...     3.0   56.7542    46.8450  Albert Lastukhin
#
#                                  url  \
# 0  https://www.xeno-canto.org/112492
# 1  https://www.xeno-canto.org/132295
# 2  https://www.xeno-canto.org/133558
# 3  https://www.xeno-canto.org/134265
# 4  https://www.xeno-canto.org/135792
#
#                                              license  class_weight_file  \
# 0  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 1  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 2  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 3  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 4  Creative Commons Attribution-NonCommercial-Sha...           0.937876
#
#    class_weight_duration  class_weight_combined  orig_index
# 0               0.419757               0.627439       13847
# 1               0.419757               0.627439       13856
# 2               0.419757               0.627439       13859
# 3               0.419757               0.627439       13860
# 4               0.419757               0.627439       13866
#
# [5 rows x 34 columns]

# %% [markdown]
# # Define extract audio function to ensure sample rate and extract audio object in np.array format using librosa

# %%
def extract_audio_librosa(filename, desired_sample_rate=16000):
  '''
  Usage: extract the audio object in np.array format from an audio file
  Input:
    filename
  Output:
    audio object in np.array format
  '''
  filepath = '/content/drive/MyDrive/207/207-Project/data/test/audio_files/' + filename
  waveform, sample_rate = librosa.load(filepath, sr=desired_sample_rate)
  if sample_rate != desired_sample_rate:
    waveform = librosa.resample(y=waveform, orig_sr = sample_rate, target_sr = desired_sample_rate)
  return waveform

# %% [markdown]
# # Extract file names

# %%
filenames = df['filename']
filenames
# Out:
# 0       thrnig1/XC112492.ogg
# 1       thrnig1/XC132295.ogg
# 2       thrnig1/XC133558.ogg
# 3       thrnig1/XC134265.ogg
# 4       thrnig1/XC135792.ogg
#                 ...
# 1397    cohmar1/XC748720.ogg
# 1398    cohmar1/XC748721.ogg
# 1399    cohmar1/XC748725.ogg
# 1400    cohmar1/XC749488.ogg
# 1401    cohmar1/XC749637.ogg
# Name: filename, Length: 1402, dtype: object

# %% [markdown]
# # Create top level directory to save the files

# %%
save_dir = '/content/drive/MyDrive/207/207-Project/data/test/librosa_loaded'

# %%
os.makedirs(save_dir, exist_ok=False)

# %% [markdown]
# # Create a list to store the file paths

# %%
filepaths = []

# %% [markdown]
# # Extract the audio files and save to disk

# %%
for i, filename in enumerate(filenames):
  audio = extract_audio_librosa(filename)

  dir = filename.split('/')[0]
  filename = filename.split('/')[1]
  filename = filename.replace('.ogg', '.npy')
  save_dir = f'/content/drive/MyDrive/207/207-Project/data/test/librosa_loaded/{dir}/'

  if os.path.exists(save_dir):
    pass
  else:
    os.makedirs(save_dir, exist_ok=True)

  save_filename = os.path.join(save_dir, filename)

  filepath = f'{dir}/{filename}'
  filepaths.append(filepath)

  with open(save_filename, 'w') as file:
    pass

  np.save(save_filename, audio)

  del audio
  del filepath

# %% [markdown]
# # Pick an example to ensure the audio object was saved successfully and correctly

# %%
example_b4 = extract_audio_librosa(filenames[0])
example_b4
# Out:
# array([-2.2763852e-06, -7.0454553e-07,  2.2521708e-06, ...,
#         1.3894627e-05, -2.4790970e-05,  1.7528437e-05], dtype=float32)

# %%
example_b4.shape
# Out:
# (936647,)

# %%
example = np.load('/content/drive/MyDrive/207/207-Project/data/test/librosa_loaded/thrnig1/XC112492.npy')
example
# Out:
# array([-2.2763852e-06, -7.0454553e-07,  2.2521708e-06, ...,
#         1.3894627e-05, -2.4790970e-05,  1.7528437e-05], dtype=float32)

# %%
example.shape
# Out:
# (936647,)

# %%
np.array_equal(example_b4, example)
# Out:
# True

# %% [markdown]
# # Pick another example to ensure the audio object was saved successfully and correctly

# %%
example_b4 = extract_audio_librosa(filenames[1401])
example_b4
# Out:
# array([9.5530231e-07, 1.3598146e-06, 1.3222638e-05, ..., 1.1540429e-05,
#        3.8615424e-05, 9.9565486e-06], dtype=float32)

# %%
example_b4.shape
# Out:
# (80640,)

# %%
example = np.load('/content/drive/MyDrive/207/207-Project/data/test/librosa_loaded/cohmar1/XC749637.npy')
example
# Out:
# array([9.5530231e-07, 1.3598146e-06, 1.3222638e-05, ..., 1.1540429e-05,
#        3.8615424e-05, 9.9565486e-06], dtype=float32)

# %%
example.shape
# Out:
# (80640,)

# %%
np.array_equal(example_b4, example)
# Out:
# True

# %% [markdown]
# # check that the filepaths were all saved correctly and add that to the original df

# %%
filepaths
# Out:
# ['thrnig1/XC112492.npy',
#  'thrnig1/XC132295.npy',
#  'thrnig1/XC133558.npy',
#  'thrnig1/XC134265.npy',
#  'thrnig1/XC135792.npy',
#  'thrnig1/XC152472.npy',
#  'thrnig1/XC152506.npy',
#  'thrnig1/XC176969.npy',
#  'thrnig1/XC178171.npy',
#  'thrnig1/XC179283.npy',
#  'thrnig1/XC180341.npy',
#  'thrnig1/XC180896.npy',
#  'thrnig1/XC181942.npy',
#  'thrnig1/XC185981.npy',
#  'thrnig1/XC186525.npy',
#  'thrnig1/XC193316.npy',
#  'thrnig1/XC194398.npy',
#  'thrnig1/XC197641.npy',
#  'thrnig1/XC198467.npy',
#  'thrnig1/XC198989.npy',
#  'thrnig1/XC199723.npy',
#  'thrnig1/XC208268.npy',
#  'barswa/XC317544.npy',
#  'barswa/XC319599.npy',
#  'barswa/XC320886.npy',
#  'barswa/XC327328.npy',
#  'barswa/XC327364.npy',
#  'barswa/XC329025.npy',
#  'barswa/XC330211.npy',
#  'barswa/XC337979.npy',
#  'barswa/XC349298.npy',
#  'barswa/XC361216.npy',
#  'barswa/XC361218.npy',
#  'barswa/XC361219.npy',
#  'barswa/XC361222.npy',
#  'barswa/XC361223.npy',
#  'barswa/XC361224.npy',
#  'barswa/XC361226.npy',
#  'barswa/XC361239.npy',
#  'barswa/XC361240.npy',
#  'barswa/XC361241.npy',
#  'barswa/XC361743.npy',
#  'barswa/XC361814.npy',
#  'barswa/XC375299.npy',
#  'barswa/XC375583.npy',
#  'barswa/XC383831.npy',
#  'barswa/XC384074.npy',
#  'barswa/XC394400.npy',
#  'barswa/XC396335.npy',
#  'barswa/XC405617.npy',
#  'barswa/XC415547.npy',
#  'barswa/XC417086.npy',
#  'barswa/XC418145.npy',
#  'barswa/XC422186.npy',
#  'barswa/XC433813.npy',
#  'barswa/XC437453.npy',
#  'barswa/XC443240.npy',
#  'barswa/XC452058.npy',
#  'barswa/XC454814.npy',
#  'barswa/XC457816.npy',
#  'barswa/XC457817.npy',
#  'barswa/XC458224.npy',
#  'barswa/XC458633.npy',
#  'barswa/XC458638.npy',
#  'barswa/XC471591.npy',
#  'barswa/XC476498.npy',
#  'barswa/XC485999.npy',
#  'barswa/XC486212.npy',
#  'barswa/XC486272.npy',
#  'barswa/XC486577.npy',
#  'barswa/XC488850.npy',
#  'barswa/XC494034.npy',
#  'barswa/XC501004.npy',
#  'barswa/XC52061.npy',
#  'barswa/XC541914.npy',
#  'barswa/XC541924.npy',
#  'barswa/XC542504.npy',
#  'barswa/XC545986.npy',
#  'barswa/XC554132.npy',
#  'barswa/XC557394.npy',
#  'barswa/XC559606.npy',
#  'barswa/XC559681.npy',
#  'barswa/XC567605.npy',
#  'barswa/XC570215.npy',
#  'barswa/XC570975.npy',
#  'barswa/XC574966.npy',
#  'barswa/XC579650.npy',
#  'barswa/XC582626.npy',
#  'barswa/XC584461.npy',
#  'barswa/XC585550.npy',
#  'barswa/XC589374.npy',
#  'barswa/XC593399.npy',
#  'barswa/XC598594.npy',
#  'barswa/XC623204.npy',
#  'barswa/XC623206.npy',
#  'barswa/XC625824.npy',
#  'barswa/XC643586.npy',
#  'barswa/XC644159.npy',
#  'barswa/XC644163.npy',
#  'barswa/XC645088.npy',
#  'barswa/XC645358.npy',
#  'barswa/XC649113.npy',
#  'barswa/XC653438.npy',
#  'barswa/XC655311.npy',
#  'barswa/XC656535.npy',
#  'barswa/XC657995.npy',
#  'barswa/XC662037.npy',
#  'barswa/XC664995.npy',
#  'barswa/XC667152.npy',
#  'barswa/XC667153.npy',
#  'barswa/XC667845.npy',
#  'barswa/XC669737.npy',
#  'barswa/XC671129.npy',
#  'barswa/XC671720.npy',
#  'barswa/XC672358.npy',
#  'barswa/XC672484.npy',
#  'barswa/XC674251.npy',
#  'barswa/XC677086.npy',
#  'barswa/XC677842.npy',
#  'barswa/XC687539.npy',
#  'barswa/XC690491.npy',
#  'barswa/XC690493.npy',
#  'barswa/XC690494.npy',
#  'barswa/XC690495.npy',
#  'barswa/XC690499.npy',
#  'barswa/XC690752.npy',
#  'barswa/XC692427.npy',
#  'barswa/XC702809.npy',
#  'barswa/XC709253.npy',
#  'barswa/XC713037.npy',
#  'barswa/XC721711.npy',
#  'barswa/XC727116.npy',
#  'barswa/XC728028.npy',
#  'barswa/XC730443.npy',
#  'barswa/XC734915.npy',
#  'barswa/XC735267.npy',
#  'barswa/XC736807.npy',
#  'barswa/XC741809.npy',
#  'barswa/XC744925.npy',
#  'barswa/XC746604.npy',
#  'barswa/XC746902.npy',
#  'barswa/XC747068.npy',
#  'barswa/XC747069.npy',
#  'barswa/XC756634.npy',
#  'barswa/XC83449.npy',
#  'woosan/XC127465.npy',
#  'woosan/XC140651.npy',
#  'woosan/XC145327.npy',
#  'woosan/XC145348.npy',
#  'woosan/XC146456.npy',
#  'woosan/XC146617.npy',
#  'woosan/XC146704.npy',
#  'woosan/XC146902.npy',
#  'woosan/XC153897.npy',
#  'woosan/XC182905.npy',
#  'woosan/XC184462.npy',
#  'woosan/XC187197.npy',
#  'woosan/XC187199.npy',
#  'woosan/XC189355.npy',
#  'woosan/XC190516.npy',
#  'woosan/XC19922.npy',
#  'woosan/XC204559.npy',
#  'woosan/XC215036.npy',
#  'woosan/XC217918.npy',
#  'woosan/XC234697.npy',
#  'woosan/XC266297.npy',
#  'woosan/XC266302.npy',
#  'woosan/XC307284.npy',
#  'woosan/XC331100.npy',
#  'woosan/XC331101.npy',
#  'woosan/XC337590.npy',
#  'woosan/XC342908.npy',
#  'woosan/XC344910.npy',
#  'woosan/XC345156.npy',
#  'woosan/XC347605.npy',
#  'woosan/XC358470.npy',
#  'woosan/XC363991.npy',
#  'woosan/XC368106.npy',
#  'woosan/XC371015.npy',
#  'woosan/XC380949.npy',
#  'woosan/XC381329.npy',
#  'woosan/XC381827.npy',
#  'woosan/XC381830.npy',
#  'woosan/XC382143.npy',
#  'woosan/XC400539.npy',
#  'woosan/XC428930.npy',
#  'woosan/XC430418.npy',
#  'woosan/XC431225.npy',
#  'woosan/XC433536.npy',
#  'woosan/XC447001.npy',
#  'woosan/XC460591.npy',
#  'woosan/XC469043.npy',
#  'woosan/XC469969.npy',
#  'woosan/XC472029.npy',
#  'woosan/XC478806.npy',
#  'woosan/XC481808.npy',
#  'woosan/XC484263.npy',
#  'woosan/XC486250.npy',
#  'woosan/XC487833.npy',
#  'woosan/XC488069.npy',
#  'woosan/XC492495.npy',
#  'woosan/XC493129.npy',
#  'woosan/XC497658.npy',
#  'woosan/XC509637.npy',
#  'woosan/XC513494.npy',
#  'woosan/XC530489.npy',
#  'woosan/XC544803.npy',
#  'woosan/XC549280.npy',
#  'woosan/XC553364.npy',
#  'woosan/XC554792.npy',
#  'woosan/XC557396.npy',
#  'woosan/XC559448.npy',
#  'woosan/XC559619.npy',
#  'woosan/XC565297.npy',
#  'woosan/XC565576.npy',
#  'woosan/XC567028.npy',
#  'woosan/XC568127.npy',
#  'woosan/XC570750.npy',
#  'woosan/XC575862.npy',
#  'woosan/XC577707.npy',
#  'woosan/XC577716.npy',
#  'woosan/XC580553.npy',
#  'woosan/XC580751.npy',
#  'woosan/XC585041.npy',
#  'woosan/XC585832.npy',
#  'woosan/XC586200.npy',
#  'woosan/XC586201.npy',
#  'woosan/XC587077.npy',
#  'woosan/XC589100.npy',
#  'woosan/XC593060.npy',
#  'woosan/XC601445.npy',
#  'woosan/XC635332.npy',
#  'woosan/XC642799.npy',
#  'woosan/XC643879.npy',
#  'woosan/XC643933.npy',
#  'woosan/XC644171.npy',
#  'woosan/XC644599.npy',
#  'woosan/XC646003.npy',
#  'woosan/XC64711.npy',
#  'woosan/XC64712.npy',
#  'woosan/XC647846.npy',
#  'woosan/XC647946.npy',
#  'woosan/XC648533.npy',
#  'woosan/XC648800.npy',
#  'woosan/XC659864.npy',
#  'woosan/XC662168.npy',
#  'woosan/XC663129.npy',
#  'woosan/XC663130.npy',
#  'woosan/XC664809.npy',
#  'woosan/XC668256.npy',
#  'woosan/XC668264.npy',
#  'woosan/XC669862.npy',
#  'woosan/XC669943.npy',
#  'woosan/XC670793.npy',
#  'woosan/XC671941.npy',
#  'woosan/XC672717.npy',
#  'woosan/XC672720.npy',
#  'woosan/XC672983.npy',
#  'woosan/XC679589.npy',
#  'woosan/XC685750.npy',
#  'woosan/XC687196.npy',
#  'woosan/XC687198.npy',
#  'woosan/XC690360.npy',
#  'woosan/XC696443.npy',
#  'woosan/XC700153.npy',
#  'woosan/XC704756.npy',
#  'woosan/XC705355.npy',
#  'woosan/XC716018.npy',
#  'woosan/XC717335.npy',
#  'woosan/XC718684.npy',
#  'woosan/XC723788.npy',
#  'woosan/XC737919.npy',
#  'woosan/XC738792.npy',
#  'woosan/XC738798.npy',
#  'woosan/XC740798.npy',
#  'woosan/XC742132.npy',
#  'woosan/XC742926.npy',
#  'woosan/XC743566.npy',
#  'woosan/XC744072.npy',
#  'woosan/XC745719.npy',
#  'woosan/XC745724.npy',
#  'woosan/XC745768.npy',
#  'woosan/XC747221.npy',
#  'woosan/XC747318.npy',
#  'woosan/XC749410.npy',
#  'woosan/XC754173.npy',
#  'woosan/XC754763.npy',
#  'combuz1/XC114415.npy',
#  'combuz1/XC125105.npy',
#  'combuz1/XC139550.npy',
#  'combuz1/XC140833.npy',
#  'combuz1/XC142380.npy',
#  'combuz1/XC144235.npy',
#  'combuz1/XC144284.npy',
#  'combuz1/XC151184.npy',
#  'combuz1/XC151185.npy',
#  'combuz1/XC156307.npy',
#  'combuz1/XC179299.npy',
#  'combuz1/XC189735.npy',
#  'combuz1/XC189736.npy',
#  'combuz1/XC189785.npy',
#  'combuz1/XC195421.npy',
#  'combuz1/XC216974.npy',
#  'combuz1/XC240250.npy',
#  'combuz1/XC254679.npy',
#  'combuz1/XC263210.npy',
#  'combuz1/XC293919.npy',
#  'combuz1/XC301895.npy',
#  'combuz1/XC305142.npy',
#  'combuz1/XC310842.npy',
#  'combuz1/XC315475.npy',
#  'combuz1/XC323547.npy',
#  'combuz1/XC326517.npy',
#  'combuz1/XC335909.npy',
#  'combuz1/XC337671.npy',
#  'combuz1/XC343993.npy',
#  'combuz1/XC344204.npy',
#  'combuz1/XC357802.npy',
#  'combuz1/XC358959.npy',
#  'combuz1/XC361871.npy',
#  'combuz1/XC363736.npy',
#  'combuz1/XC375235.npy',
#  'combuz1/XC382539.npy',
#  'combuz1/XC383936.npy',
#  'combuz1/XC387618.npy',
#  'combuz1/XC403178.npy',
#  'combuz1/XC405097.npy',
#  'combuz1/XC419543.npy',
#  'combuz1/XC42427.npy',
#  'combuz1/XC424544.npy',
#  'combuz1/XC441885.npy',
#  'combuz1/XC448429.npy',
#  'combuz1/XC451007.npy',
#  'combuz1/XC480593.npy',
#  'combuz1/XC485623.npy',
#  'combuz1/XC486944.npy',
#  'combuz1/XC490034.npy',
#  'combuz1/XC496715.npy',
#  'combuz1/XC499455.npy',
#  'combuz1/XC502262.npy',
#  'combuz1/XC509240.npy',
#  'combuz1/XC511684.npy',
#  'combuz1/XC513468.npy',
#  'combuz1/XC522513.npy',
#  'combuz1/XC533173.npy',
#  'combuz1/XC533691.npy',
#  'combuz1/XC533692.npy',
#  'combuz1/XC533897.npy',
#  'combuz1/XC545293.npy',
#  'combuz1/XC549048.npy',
#  'combuz1/XC552836.npy',
#  'combuz1/XC555949.npy',
#  'combuz1/XC576520.npy',
#  'combuz1/XC578537.npy',
#  'combuz1/XC579720.npy',
#  'combuz1/XC579895.npy',
#  'combuz1/XC581056.npy',
#  'combuz1/XC581967.npy',
#  'combuz1/XC584693.npy',
#  'combuz1/XC605687.npy',
#  'combuz1/XC606998.npy',
#  'combuz1/XC612901.npy',
#  'combuz1/XC613336.npy',
#  'combuz1/XC614108.npy',
#  'combuz1/XC617082.npy',
#  'combuz1/XC618756.npy',
#  'combuz1/XC619487.npy',
#  'combuz1/XC619514.npy',
#  'combuz1/XC621679.npy',
#  'combuz1/XC622410.npy',
#  'combuz1/XC623200.npy',
#  'combuz1/XC625438.npy',
#  'combuz1/XC627886.npy',
#  'combuz1/XC628957.npy',
#  'combuz1/XC631740.npy',
#  'combuz1/XC636833.npy',
#  'combuz1/XC637086.npy',
#  'combuz1/XC637599.npy',
#  'combuz1/XC637884.npy',
#  'combuz1/XC638478.npy',
#  'combuz1/XC638480.npy',
#  'combuz1/XC638482.npy',
#  'combuz1/XC638483.npy',
#  'combuz1/XC638485.npy',
#  'combuz1/XC638629.npy',
#  'combuz1/XC638807.npy',
#  'combuz1/XC640964.npy',
#  'combuz1/XC641994.npy',
#  'combuz1/XC644448.npy',
#  'combuz1/XC647785.npy',
#  'combuz1/XC647788.npy',
#  'combuz1/XC649191.npy',
#  'combuz1/XC649218.npy',
#  'combuz1/XC658351.npy',
#  'combuz1/XC659695.npy',
#  'combuz1/XC662308.npy',
#  'combuz1/XC662573.npy',
#  'combuz1/XC663005.npy',
#  'combuz1/XC665246.npy',
#  ...]

# %%
len(df) == len(filepaths)
# Out:
# True

# %%
df['librosa_loaded'] = filepaths

# %%
df.head()
# Out:
#   primary_label         common_name    scientific_name  species_rank  \
# 0       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 1       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 2       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 3       thrnig1  Thrush Nightingale  Luscinia luscinia             0
# 4       thrnig1  Thrush Nightingale  Luscinia luscinia             0
#
#                filename dataset  duration_secs  duration_mins  duration_hrs  \
# 0  thrnig1/XC112492.ogg    test      58.540408       0.975673      0.016261
# 1  thrnig1/XC132295.ogg    test      73.769796       1.229497      0.020492
# 2  thrnig1/XC133558.ogg    test      78.759229       1.312654      0.021878
# 3  thrnig1/XC134265.ogg    test     394.187755       6.569796      0.109497
# 4  thrnig1/XC135792.ogg    test      42.344535       0.705742      0.011762
#
#    species_total_files  ...  latitude  longitude            author  \
# 0                  499  ...   59.8510    17.6230        Sander Bot
# 1                  499  ...   56.0889    47.2543  Albert Lastukhin
# 2                  499  ...   61.5650    29.5650     Stuart Fisher
# 3                  499  ...   51.3506    23.0467    Jarek Matusiak
# 4                  499  ...   56.7542    46.8450  Albert Lastukhin
#
#                                  url  \
# 0  https://www.xeno-canto.org/112492
# 1  https://www.xeno-canto.org/132295
# 2  https://www.xeno-canto.org/133558
# 3  https://www.xeno-canto.org/134265
# 4  https://www.xeno-canto.org/135792
#
#                                              license  class_weight_file  \
# 0  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 1  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 2  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 3  Creative Commons Attribution-NonCommercial-Sha...           0.937876
# 4  Creative Commons Attribution-NonCommercial-Sha...           0.937876
#
#    class_weight_duration  class_weight_combined  orig_index  \
# 0               0.419757               0.627439       13847
# 1               0.419757               0.627439       13856
# 2               0.419757               0.627439       13859
# 3               0.419757               0.627439       13860
# 4               0.419757               0.627439       13866
#
#          librosa_loaded
# 0  thrnig1/XC112492.npy
# 1  thrnig1/XC132295.npy
# 2  thrnig1/XC133558.npy
# 3  thrnig1/XC134265.npy
# 4  thrnig1/XC135792.npy
#
# [5 rows x 35 columns]

# %% [markdown]
# # load one example from df and use in a librosa function to confirm the object is usable

# %%
example_og = extract_audio_librosa(df['filename'][0])
example_og_rms = librosa.feature.rms(y=example_og)
example_og_rms
# Out:
# array([[0.00618627, 0.0077443 , 0.01076956, ..., 0.00737438, 0.00637029,
#         0.0050477 ]], dtype=float32)

# %%
example_new = np.load('/content/drive/MyDrive/207/207-Project/data/test/librosa_loaded/' + df['librosa_loaded'][0])
example_new_rms = librosa.feature.rms(y=example_new)
example_new_rms
# Out:
# array([[0.00618627, 0.0077443 , 0.01076956, ..., 0.00737438, 0.00637029,
#         0.0050477 ]], dtype=float32)

# %%
np.array_equal(example_og_rms, example_new_rms)
# Out:
# True
